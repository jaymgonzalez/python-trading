# %%
import pandas as pd
import pandas_ta as ta
import yfinance as yf

# %%
df = yf.download('amzn', period='1y', interval='1H')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2022-03-09 12:30:00  137.985504  139.389999  137.985504  139.217010
# 2022-03-09 13:30:00  139.165253  139.378510  138.454010  138.783997
# 2022-03-09 14:30:00  138.792511  140.250000  138.685501  139.695755
# 2022-03-09 15:30:00  139.705002  139.878006  138.512497  139.237000
# 2022-03-10 09:30:00  145.684998  147.748749  143.977997  146.296249
# ...                         ...         ...         ...         ...
# 2023-03-08 15:30:00   93.464996   94.029999   93.404999   93.919998
# 2023-03-09 09:30:00   93.680000   95.800003   93.559998   95.720001
# 2023-03-09 10:30:00   95.720001   96.160004   95.139999   95.180901
# 2023-03-09 11:30:00   95.190002   95.824997   95.099998   95.366699
# 2023-03-09 12:30:00   95.370003   95.464996   94.660004   94.855003
#
#                       Adj Close    Volume
# Datetime
# ...

# %%
help(df.ta.indicators)
# Out:
# Help on method indicators in module pandas_ta.core:
#
# indicators(**kwargs) method of pandas_ta.core.AnalysisIndicators instance
#     List of Indicators
#
#     kwargs:
#         as_list (bool, optional): When True, it returns a list of the
#             indicators. Default: False.
#         exclude (list, optional): The passed in list will be excluded
#             from the indicators list. Default: None.
#
#     Returns:
#         Prints the list of indicators. If as_list=True, then a list.
